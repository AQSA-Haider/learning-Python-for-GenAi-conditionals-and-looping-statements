# %% [markdown]
# ## Aqsa Haider
# ## Python Conditionals,Looping And Loop Control Statements: Task-2.1,Task-2.2,Task-2.3 & Task-2.4
#
#  These Repository contains a clear implementation of fundamental python conditionals (if/elif,else statements)looping (for,while loops) and loop control(break,continue,pass)statements,
#
# ## How to run the code:
# #Navigate to the project folder in your terminal :

# %% [markdown]
# ## Bash
# https://github.com/AQSA-Haider/learning-Python-for-GenAi-conditionals-and-looping-statements.git

# %% [markdown]
# ## Launch Jupiter Notebook:

# %% [markdown]
# ## Bash
# jupiter notebook

# %% [markdown]
# ## Run the file:
# Assignment2.ipynb
# ## and press
# shift + enter
# ## to run the cells Sequentially
